# %%
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
billboard_df = pd.read_pickle("./data/billboard_rankings.pickle")

# %%
spotify_df = pd.read_pickle("./data/audio_features.pickle")
spotify_df
# Out:
#                                                   songid  \
# 0                          AdictoTainy, Anuel AA & Ozuna
# 1      The Ones That Didn't Make It Back HomeJustin M...
# 2                      ShallowLady Gaga & Bradley Cooper
# 3                    EnemiesPost Malone Featuring DaBaby
# 4        Bacc At It AgainYella Beezy, Gucci Mane & Quavo
# 5                                 The ArcherTaylor Swift
# 6                                            VIBEZDaBaby
# 7                                       When I Grow UpNF
# 8                        Hollywood's BleedingPost Malone
# 9      What Happens In A Small TownBrantley Gilbert +...
# 10                                 Famous HoesNLE Choppa
# 11                           Cornelia StreetTaylor Swift
# 12                       HeatChris Brown Featuring Gunna
# 13                            Te RobareNicky Jam X Ozuna
# 14                             Yellow HeartsAnt Saunders
# ...

# %%
billboard_df
# Out:
#                                                       url      weekid  \
# 0       http://www.billboard.com/charts/hot-100/1958-0...  1958-08-02
# 1       http://www.billboard.com/charts/hot-100/1995-1...  1995-12-02
# 2       http://www.billboard.com/charts/hot-100/1997-1...  1997-10-11
# 3       http://www.billboard.com/charts/hot-100/2006-0...  2006-07-01
# 4       http://www.billboard.com/charts/hot-100/2009-1...  2009-10-24
# 5       http://www.billboard.com/charts/hot-100/2011-0...  2011-02-26
# 6       http://www.billboard.com/charts/hot-100/2012-0...  2012-03-03
# 7       http://www.billboard.com/charts/hot-100/2014-0...  2014-09-06
# 8       http://www.billboard.com/charts/hot-100/2016-0...  2016-02-20
# 9       http://www.billboard.com/charts/hot-100/2016-0...  2016-05-28
# 10      http://www.billboard.com/charts/hot-100/2017-0...  2017-01-28
# 11      https://www.billboard.com/charts/hot-100/2018-...  2018-11-17
# ...

# %%
billboard_df["year"] = billboard_df["weekid"].str[0:4]
billboard_df["year"] = billboard_df["year"].astype(int)
billboard_df
# Out:
#                                                       url      weekid  \
# 0       http://www.billboard.com/charts/hot-100/1958-0...  1958-08-02
# 1       http://www.billboard.com/charts/hot-100/1995-1...  1995-12-02
# 2       http://www.billboard.com/charts/hot-100/1997-1...  1997-10-11
# 3       http://www.billboard.com/charts/hot-100/2006-0...  2006-07-01
# 4       http://www.billboard.com/charts/hot-100/2009-1...  2009-10-24
# 5       http://www.billboard.com/charts/hot-100/2011-0...  2011-02-26
# 6       http://www.billboard.com/charts/hot-100/2012-0...  2012-03-03
# 7       http://www.billboard.com/charts/hot-100/2014-0...  2014-09-06
# 8       http://www.billboard.com/charts/hot-100/2016-0...  2016-02-20
# 9       http://www.billboard.com/charts/hot-100/2016-0...  2016-05-28
# 10      http://www.billboard.com/charts/hot-100/2017-0...  2017-01-28
# 11      https://www.billboard.com/charts/hot-100/2018-...  2018-11-17
# ...

# %%
blillboard_df_1960s = billboard_df[billboard_df["year"] >= 1960]
blillboard_df_1960s = blillboard_df_1960s[blillboard_df_1960s["year"]<=1969]
blillboard_df_1960s= blillboard_df_1960s.groupby(["performer", "song","songid"]).agg({"week_position":"min", "year":"min"})
with open("/Users/jkocher/Documents/airflow_home/data/blillboard_df_1960s.pickle", 'wb') as d:
    pickle.dump(blillboard_df_1960s, d)

# %%
blillboard_df_1970s = billboard_df[billboard_df["year"] >= 1970]
blillboard_df_1970s = blillboard_df_1970s[blillboard_df_1970s["year"]<=1979]
blillboard_df_1970s = blillboard_df_1970s.groupby(["performer", "song","songid"]).agg({"week_position":"min", "year":"min"})
with open("/Users/jkocher/Documents/airflow_home/data/blillboard_df_1970s.pickle", 'wb') as d:
    pickle.dump(blillboard_df_1970s, d)

# %%
blillboard_df_1980s = billboard_df[billboard_df["year"] >= 1980]
blillboard_df_1980s = blillboard_df_1980s[blillboard_df_1980s["year"]<=1989]
blillboard_df_1980s = blillboard_df_1980s.groupby(["performer", "song","songid"]).agg({"week_position":"min", "year":"min"})
with open("/Users/jkocher/Documents/airflow_home/data/blillboard_df_1980s.pickle", 'wb') as d:
    pickle.dump(blillboard_df_1980s, d)

# %%
blillboard_df_1990s = billboard_df[billboard_df["year"] >= 1990]
blillboard_df_1990s = blillboard_df_1990s[blillboard_df_1990s["year"]<=1999]
blillboard_df_1990s = blillboard_df_1990s.groupby(["performer", "song","songid"]).agg({"week_position":"min", "year":"min"})
with open("/Users/jkocher/Documents/airflow_home/data/blillboard_df_1990s.pickle", 'wb') as d:
    pickle.dump(blillboard_df_1990s, d)

# %%
blillboard_df_2000s = billboard_df[billboard_df["year"] >= 2000]
blillboard_df_2000s = blillboard_df_2000s[blillboard_df_2000s["year"]<=2009]
blillboard_df_2000s = blillboard_df_2000s.groupby(["performer", "song","songid"]).agg({"week_position":"min", "year":"min"})
with open("/Users/jkocher/Documents/airflow_home/data/blillboard_df_2000s.pickle", 'wb') as d:
    pickle.dump(blillboard_df_2000s, d)

# %%
blillboard_df_2010s = billboard_df[billboard_df["year"] >= 2010]
blillboard_df_2010s = blillboard_df_2010s[blillboard_df_2010s["year"]<=2019]
blillboard_df_2010s = blillboard_df_2010s.groupby(["song","performer","songid"]).agg({"week_position":"min", "year":"min"})
with open("/Users/jkocher/Documents/airflow_home/data/blillboard_df_2010s.pickle", 'wb') as d:
    pickle.dump(blillboard_df_2010s, d)

# %%
blillboard_df_2010s = pd.read_pickle("/Users/jkocher/Documents/airflow_home/data/blillboard_df_2010s.pickle")
blillboard_df_2010s
# Out:
#                                                                                                                                                           week_position  \
# song                                               performer                                          songid
# #Beautiful                                         Mariah Carey Featuring Miguel                      #BeautifulMariah Carey Featuring Miguel                        15
# #SELFIE                                            The Chainsmokers                                   #SELFIEThe Chainsmokers                                        16
# #thatPOWER                                         will.i.am Featuring Justin Bieber                  #thatPOWERwill.i.am Featuring Justin Bieber                    17
# $ave Dat Money                                     Lil Dicky Featuring Fetty Wap & Rich Homie Quan    $ave Dat MoneyLil Dicky Featuring Fetty Wap & R...             71
# ...

# %%
blillboard_df_2010s = pd.read_pickle("/Users/jkocher/Documents/airflow_home/data/blillboard_df_2010s.pickle")
spotify_df = pd.read_pickle("./data/audio_features.pickle")
top2010_df = pd.merge(blillboard_df_2010s, spotify_df, left_on = "songid", right_on = "songid", how= "left")
top2010_df= top2010_df.dropna(subset=["key"])
with open("/Users/jkocher/Documents/airflow_home/data/blillboard_spotify_2010s.pickle", 'wb') as d:
    pickle.dump(top2010_df, d)

# %%
blillboard_df_2000s = pd.read_pickle("/Users/jkocher/Documents/airflow_home/data/blillboard_df_2000s.pickle")
spotify_df = pd.read_pickle("./data/audio_features.pickle")
top2000_df = pd.merge(blillboard_df_2000s, spotify_df, left_on = "songid", right_on = "songid", how= "left")
top2000_df= top2000_df.dropna(subset=["key"])
with open("/Users/jkocher/Documents/airflow_home/data/blillboard_spotify_2000s.pickle", 'wb') as d:
    pickle.dump(top2000_df, d)

# %%
blillboard_df_1990s = pd.read_pickle("/Users/jkocher/Documents/airflow_home/data/blillboard_df_1990s.pickle")
spotify_df = pd.read_pickle("./data/audio_features.pickle")
top1990_df = pd.merge(blillboard_df_1990s, spotify_df, left_on = "songid", right_on = "songid", how= "left")
top1990_df= top1990_df.dropna(subset=["key"])
with open("/Users/jkocher/Documents/airflow_home/data/blillboard_spotify_1990s.pickle", 'wb') as d:
    pickle.dump(top1990_df, d)

# %%
blillboard_df_1980s = pd.read_pickle("/Users/jkocher/Documents/airflow_home/data/blillboard_df_1980s.pickle")
spotify_df = pd.read_pickle("./data/audio_features.pickle")
top1980_df = pd.merge(blillboard_df_1980s, spotify_df, left_on = "songid", right_on = "songid", how= "left")
top1980_df= top1980_df.dropna(subset=["key"])
with open("/Users/jkocher/Documents/airflow_home/data/blillboard_spotify_1980s.pickle", 'wb') as d:
    pickle.dump(top1980_df, d)

# %%
blillboard_df_1970s = pd.read_pickle("/Users/jkocher/Documents/airflow_home/data/blillboard_df_1970s.pickle")
spotify_df = pd.read_pickle("./data/audio_features.pickle")
top1970_df = pd.merge(blillboard_df_1970s, spotify_df, left_on = "songid", right_on = "songid", how= "left")
top1970_df= top1970_df.dropna(subset=["key"])
with open("/Users/jkocher/Documents/airflow_home/data/blillboard_spotify_1970s.pickle", 'wb') as d:
    pickle.dump(top1970_df, d)

# %%
blillboard_df_1960s = pd.read_pickle("/Users/jkocher/Documents/airflow_home/data/blillboard_df_1960s.pickle")
spotify_df = pd.read_pickle("./data/audio_features.pickle")
top1960_df = pd.merge(blillboard_df_1960s, spotify_df, left_on = "songid", right_on = "songid", how= "left")
top1960_df= top1960_df.dropna(subset=["key"])
with open("/Users/jkocher/Documents/airflow_home/data/blillboard_spotify_1960s.pickle", 'wb') as d:
    pickle.dump(top1960_df, d)

# %%
genre_list = []
sub_genre_lst = []

for genre in top1960_df["spotify_genre"]:
    if type(genre) == str and genre != "[]":
        genre = genre.replace("[", "")
        genre = genre.replace("]", "")
        genre = genre.replace("'", "")
        #genre = genre.replace(" ", "")
        x = genre.split(",")
        genre_list.append(x)
        
for genre in genre_list:
    for sub_genre in genre:
        sub_genre_lst.append(sub_genre)
        
genre_pd_1960s = pd.DataFrame(sub_genre_lst)
genre_pd_1960s = genre_pd_1960s.rename(columns={0: "genre"})
genre_pd_1960s = genre_pd_1960s['genre'].str.lstrip(" ")

genre_pd_1960s.value_counts()
# Out:
# brill building pop          2097
# adult standards             1684
# rock-and-roll               1315
# soul                        1160
# bubblegum pop               1125
# motown                      1120
# folk rock                    874
# classic soul                 822
# merseybeat                   667
# rhythm and blues             653
# southern soul                650
# lounge                       629
# mellow gold                  609
# rockabilly                   571
# doo-wop                      508
# funk                         432
# easy listening               430
# rock                         407
# quiet storm                  396
# psychedelic rock             381
# soft rock                    369
# british invasion             361
# classic rock                 357
# folk                         300
# vocal jazz                   300
# classic uk pop               265
# northern soul                210
# disco                        205
# ...

# %%
top1960_df_top10 = top1960_df[top1960_df['week_position']< 800000]

# %%
top1960_df.plot(kind='scatter',x='week_position',y='spotify_track_duration_ms',color='red', title = "1960s Track Duration")
plt.show()

# %%
top1960_df[top1960_df['spotify_track_duration_ms']> 800000]
# Out:
#                                        songid  week_position  year  \
# 2415  By The Time I Get To PhoenixIsaac Hayes             37  1969
#
#         performer                          song  \
# 2415  Isaac Hayes  By The Time I Get To Phoenix
#
#                                           spotify_genre  \
# 2415  ['classic soul', 'disco', 'funk', 'jazz funk',...
#
#             spotify_track_id spotify_track_preview_url spotify_track_album  \
# 2415  1S73njkLJ5orszfbNeqDQs                       NaN   Hot Buttered Soul
#
#      spotify_track_explicit  ...  key  loudness  mode  speechiness  \
# 2415                  False  ...  8.0   -13.547  True       0.0451
#
#       acousticness  instrumentalness liveness  valence    tempo  \
# 2415         0.215          0.000083     0.13    0.069  146.594
#
#       time_signature
# 2415             4.0
#
# [1 rows x 24 columns]

# %%
top1960_df.hist(column = "spotify_track_duration_ms" )
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x145ee9f10>]],
#       dtype=object)

# %%
top1960_df_without_outlier = top1960_df[top1960_df['spotify_track_duration_ms']< 500000]
top1960_df_without_outlier.hist(column = "spotify_track_duration_ms")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x142707e50>]],
#       dtype=object)

# %%
top1960_df['spotify_track_duration_ms'].describe()
# Out:
# count    5.293000e+03
# mean     1.651961e+05
# std      4.091827e+04
# min      6.130600e+04
# 25%      1.424250e+05
# 50%      1.588800e+05
# 75%      1.770260e+05
# max      1.124153e+06
# Name: spotify_track_duration_ms, dtype: float64

# %%
top1960_df_seconds = top1960_df['spotify_track_duration_ms']*0.001
top1960_df_seconds.describe()
# Out:
# count    5293.000000
# mean      165.196054
# std        40.918272
# min        61.306000
# 25%       142.425000
# 50%       158.880000
# 75%       177.026000
# max      1124.153000
# Name: spotify_track_duration_ms, dtype: float64

# %%
top1960_df.plot(kind='scatter',x='week_position',y='loudness',color='red')

# %%
top1960_df["loudness"].describe()
# Out:
# count    5294.000000
# mean      -10.398376
# std         3.437607
# min       -28.030000
# 25%       -12.424000
# 50%       -10.066500
# 75%        -8.026250
# max        -0.507000
# Name: loudness, dtype: float64

# %%
top1960_df.hist(column = "loudness")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11f6a6ad0>]],
#       dtype=object)

# %%
top1960_df.plot(kind='scatter',x='week_position',y='danceability',color='red')
plt.show()

# %%
top1960_df.hist(column = "danceability")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11a46f710>]],
#       dtype=object)

# %%
top1960_df["danceability"].describe()
# Out:
# count    5294.000000
# mean        0.530539
# std         0.146730
# min         0.105000
# 25%         0.431000
# 50%         0.538000
# 75%         0.637000
# max         0.922000
# Name: danceability, dtype: float64

# %%
top1960_df.plot(kind='scatter',x='week_position',y='energy',color='red')
plt.show()

# %%
top1960_df.hist(column = "energy")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1325a3690>]],
#       dtype=object)

# %%
top1960_df["energy"].describe()
# Out:
# count    5294.000000
# mean        0.514308
# std         0.196546
# min         0.000581
# 25%         0.368000
# 50%         0.508000
# 75%         0.660750
# max         0.994000
# Name: energy, dtype: float64

# %%
top1960_df.plot(kind='scatter',x='week_position',y='key',color='red')
plt.show()

# %%
top1960_df["key"].nunique()
# Out:
# 12

# %%
top1960_df.hist(column = "key", bins = 12,ec='black')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1413826d0>]],
#       dtype=object)

# %%
top1960_df.plot(kind='scatter',x='week_position',y='speechiness',color='red')
plt.show()

# %%
top1960_df.hist(column = "acousticness")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x141509390>]],
#       dtype=object)

# %%
top1960_df.plot(kind='scatter',x='week_position',y='acousticness',color='red')
plt.show()

# %%
top1960_df["acousticness"].describe()
# Out:
# count    5294.000000
# mean        0.529903
# std         0.272774
# min         0.000006
# 25%         0.303000
# 50%         0.582000
# 75%         0.760000
# max         0.991000
# Name: acousticness, dtype: float64

# %%
top1960_df.hist(column = "valence")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x141f3c850>]],
#       dtype=object)

# %%
top1960_df["valence"].describe()
# Out:
# count    5294.000000
# mean        0.661562
# std         0.228617
# min         0.037700
# 25%         0.492000
# 50%         0.696000
# 75%         0.862000
# max         0.991000
# Name: valence, dtype: float64

# %%
top1960_df.plot(kind='scatter',x='week_position',y='tempo',color='red')
plt.show()

# %%
top1960_df.hist(column = "tempo")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x142230250>]],
#       dtype=object)

# %%
top1960_df["tempo"].describe()
# Out:
# count    5294.000000
# mean      119.289582
# std        29.153850
# min        35.716000
# 25%        98.076750
# 50%       116.799000
# 75%       134.983000
# max       241.009000
# Name: tempo, dtype: float64

# %%
top1960_df["time_signature"].nunique()
# Out:
# 4

# %%
top1960_df.hist(column = "time_signature", bins = 10, ec='black')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x14255fd50>]],
#       dtype=object)

# %%
mode_1960s = top1960_df["mode"]
mode_1960s=mode_1960s.replace(to_replace=True, value="Major")
mode_1960s=mode_1960s.replace(to_replace=False, value="Minor")
mode_1960s.value_counts()
# Out:
# Major    4442
# Minor     852
# Name: mode, dtype: int64

# %%
top1960_df.corr()
# Out:
#                            week_position      year  spotify_track_duration_ms  \
# week_position                   1.000000  0.050813                  -0.018416
# year                            0.050813  1.000000                   0.271300
# spotify_track_duration_ms      -0.018416  0.271300                   1.000000
# spotify_track_popularity       -0.500860  0.122239                   0.142435
# danceability                   -0.043668  0.020438                  -0.131624
# energy                         -0.058540  0.115966                  -0.113711
# key                            -0.010832  0.008403                  -0.002471
# loudness                       -0.035463  0.026070                  -0.114874
# speechiness                    -0.000630 -0.037701                   0.044412
# acousticness                    0.079551 -0.352449                  -0.053378
# instrumentalness                0.037423 -0.045724                  -0.006221
# ...

# %%
array = [0,2,5,7]
song1960s = top1960_df[top1960_df["key"].isin(array)]
song1960s = song1960s[song1960s["time_signature"]==4]
song1960s = song1960s[song1960s["time_signature"]==4]
song1960s = song1960s[song1960s["spotify_track_duration_ms"] > 1.500000e+05]
song1960s = song1960s[song1960s["spotify_track_duration_ms"] < 1.800000e+05]
song1960s = song1960s[song1960s["loudness"] > -11]
song1960s = song1960s[song1960s["loudness"] < -9]
song1960s = song1960s[song1960s["danceability"] > .45]
song1960s = song1960s[song1960s["danceability"] < .6]
song1960s = song1960s[song1960s["energy"] > .40]
song1960s = song1960s[song1960s["energy"] < .6]
song1960s = song1960s[song1960s["acousticness"] > .55]
song1960s = song1960s[song1960s["acousticness"] < .65]
song1960s = song1960s[song1960s["valence"] > .65]
song1960s = song1960s[song1960s["tempo"] > 100]
song1960s = song1960s[song1960s["tempo"] < 120]
song1960s
# Out:
#                              songid  week_position  year        performer  \
# 713   Do What You Gotta DoBobby Vee             83  1968        Bobby Vee
# 4892  New Mexican RoseThe 4 Seasons             36  1963    The 4 Seasons
# 6467         My GirlThe Temptations              1  1965  The Temptations
#
#                       song                                      spotify_genre  \
# 713   Do What You Gotta Do  ['adult standards', 'brill building pop', 'bub...
# 4892      New Mexican Rose  ['adult standards', 'brill building pop', 'bub...
# 6467               My Girl  ['adult standards', 'brill building pop', 'cla...
#
#             spotify_track_id  \
# 713   4j2ArHvM38V1LxLhhrY5Ks
# 4892  0NYARSjTaMT67cbW3JozJI
# 6467  745H5CctFr12Mo7cqa1BMH
#
#                               spotify_track_preview_url  \
# 713                                                 NaN
# 4892  https://p.scdn.co/mp3-preview/45a21e54432aa00c...
# 6467                                                NaN
#
# ...

# %%
genre_list = []
sub_genre_lst = []

for genre in top1970_df["spotify_genre"]:
    if type(genre) == str and genre != "[]":
        genre = genre.replace("[", "")
        genre = genre.replace("]", "")
        genre = genre.replace("'", "")
        #genre = genre.replace(" ", "")
        x = genre.split(",")
        genre_list.append(x)
        
for genre in genre_list:
    for sub_genre in genre:
        sub_genre_lst.append(sub_genre)
        
genre_pd_1970s = pd.DataFrame(sub_genre_lst)
genre_pd_1970s = genre_pd_1970s.rename(columns={0: "genre"})
genre_pd_1970s = genre_pd_1970s['genre'].str.lstrip(" ")

genre_pd_1970s.value_counts()
# Out:
# mellow gold                   1426
# soft rock                     1354
# classic rock                   981
# folk rock                      944
# motown                         931
# rock                           907
# soul                           901
# adult standards                846
# album rock                     837
# funk                           772
# disco                          765
# classic soul                   755
# quiet storm                    733
# country rock                   697
# bubblegum pop                  578
# folk                           520
# brill building pop             505
# southern soul                  481
# hard rock                      401
# art rock                       382
# blues rock                     375
# roots rock                     374
# classic uk pop                 352
# yacht rock                     310
# singer-songwriter              290
# psychedelic rock               256
# post-disco                     222
# ...

# %%
top1970_df.plot(kind='scatter',x='week_position',y='spotify_track_duration_ms',color='red', title = "1970s Track Duration")
plt.show()

# %%
top1970_df[top1970_df['spotify_track_duration_ms']> 1200000]
# Out:
#                           songid  week_position  year      performer  \
# 2816           AutobahnKraftwerk             25  1975      Kraftwerk
# 3251  Tubular BellsMike Oldfield              7  1974  Mike Oldfield
#
#                song                                      spotify_genre  \
# 2816       Autobahn  ['dance rock', 'dusseldorf electronic', 'elect...
# 3251  Tubular Bells  ['album rock', 'art rock', 'new age', 'progres...
#
#             spotify_track_id  \
# 2816  31uidLEHAcF8Cw1cX1VCS8
# 3251  7ERSQrRptZVM7q3VOdM7OL
#
#                               spotify_track_preview_url  \
# 2816  https://p.scdn.co/mp3-preview/add1a939f1be6d55...
# 3251                                                NaN
#
#            spotify_track_album spotify_track_explicit  ...  key  loudness  \
# 2816  Autobahn (2009 Remaster)                  False  ...  2.0   -15.606
# 3251             Tubular Bells                  False  ...  4.0   -19.104
#
# ...

# %%
top1970_df_seconds = top1970_df['spotify_track_duration_ms']*0.001
top1970_df_seconds.hist()

# %%
top1970_df_seconds.describe()
# Out:
# count    4283.000000
# mean      232.815447
# std        83.052494
# min        67.749000
# 25%       183.679500
# 50%       213.026000
# 75%       256.819500
# max      1561.133000
# Name: spotify_track_duration_ms, dtype: float64

# %%
top1970_df.hist(column = "loudness")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x14d718ad0>]],
#       dtype=object)

# %%
top1970_df["loudness"].describe()
# Out:
# count    4285.000000
# mean      -10.419440
# std         3.300703
# min       -27.010000
# 25%       -12.575000
# 50%       -10.235000
# 75%        -8.080000
# max         2.291000
# Name: loudness, dtype: float64

# %%
top1970_df.hist(column = "danceability")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x14d523890>]],
#       dtype=object)

# %%
top1970_df["danceability"].describe()
# Out:
# count    4285.000000
# mean        0.571831
# std         0.147835
# min         0.103000
# 25%         0.470000
# 50%         0.581000
# 75%         0.679000
# max         0.961000
# Name: danceability, dtype: float64

# %%
top1970_df.hist(column = "energy")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x14d90fad0>]],
#       dtype=object)

# %%
top1970_df["energy"].describe()
# Out:
# count    4285.000000
# mean        0.586836
# std         0.196118
# min         0.022000
# 25%         0.439000
# 50%         0.591000
# 75%         0.737000
# max         0.995000
# Name: energy, dtype: float64

# %%
top1970_df["key"].nunique()
# Out:
# 12

# %%
top1970_df.hist(column = "key", bins = 12,ec='black')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x14da178d0>]],
#       dtype=object)

# %%
top1970_df.hist(column = "acousticness")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x14dc4ec90>]],
#       dtype=object)

# %%
top1970_df["acousticness"].describe()
# Out:
# count    4285.000000
# mean        0.338620
# std         0.269371
# min         0.000008
# 25%         0.096400
# 50%         0.284000
# 75%         0.552000
# max         0.988000
# Name: acousticness, dtype: float64

# %%
top1970_df.hist(column = "valence")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x14dc4e990>]],
#       dtype=object)

# %%
top1970_df["valence"].describe()
# Out:
# count    4285.000000
# mean        0.666165
# std         0.227749
# min         0.035900
# 25%         0.504000
# 50%         0.708000
# 75%         0.862000
# max         0.990000
# Name: valence, dtype: float64

# %%
top1970_df.hist(column = "tempo")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x14e013810>]],
#       dtype=object)

# %%
top1970_df["tempo"].describe()
# Out:
# count    4285.000000
# mean      119.470824
# std        26.235220
# min        37.114000
# 25%       101.307000
# 50%       118.158000
# 75%       133.431000
# max       216.200000
# Name: tempo, dtype: float64

# %%
top1970_df["time_signature"].nunique()
# Out:
# 4

# %%
mode_1970s = top1970_df["mode"]
mode_1970s=mode_1970s.replace(to_replace=True, value="Major")
mode_1970s=mode_1970s.replace(to_replace=False, value="Minor")
mode_1970s.value_counts()
# Out:
# Major    3263
# Minor    1022
# Name: mode, dtype: int64

# %%
top1970_df.hist(column = "time_signature", bins = 10, ec='black')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x14dfea350>]],
#       dtype=object)

# %%
array = [0,2,7,9]
song1970s = top1970_df[top1970_df["week_position"]==1]
#song1970s = song1970s[song1970s["key"].isin(array)]
song1970s = song1970s[song1970s["time_signature"]==4]
song1970s = song1970s[song1970s["spotify_track_duration_ms"] > 2.200000e+05]
song1970s = song1970s[song1970s["spotify_track_duration_ms"] < 2.400000e+05]
song1970s = song1970s[song1970s["loudness"] > -11]
song1970s = song1970s[song1970s["loudness"] < -9]
song1970s = song1970s[song1970s["danceability"] > .51]
song1970s = song1970s[song1970s["danceability"] < .65]
song1970s = song1970s[song1970s["energy"] > .55]
song1970s = song1970s[song1970s["energy"] < .65]
song1970s = song1970s[song1970s["acousticness"] < .3]
song1970s = song1970s[song1970s["valence"] > .75]
song1970s = song1970s[song1970s["tempo"] > 105]
song1970s = song1970s[song1970s["tempo"] < 130]
song1970s
# Out:
#                      songid  week_position  year      performer      song  \
# 4141  Sir DukeStevie Wonder              1  1977  Stevie Wonder  Sir Duke
#
#                                           spotify_genre  \
# 4141  ['adult standards', 'motown', 'quiet storm', '...
#
#             spotify_track_id spotify_track_preview_url  \
# 4141  4pNiE4LCVV74vfIBaUHm1b                       NaN
#
#            spotify_track_album spotify_track_explicit  ...  key  loudness  \
# 4141  Songs In The Key Of Life                  False  ...  6.0    -9.766
#
#       mode  speechiness  acousticness  instrumentalness liveness  valence  \
# 4141  True       0.0672          0.16               0.0   0.0792    0.952
#
#         tempo  time_signature
# 4141  106.938             4.0
#
# [1 rows x 24 columns]

# %%
genre_list = []
sub_genre_lst = []

for genre in top1980_df["spotify_genre"]:
    if type(genre) == str and genre != "[]":
        genre = genre.replace("[", "")
        genre = genre.replace("]", "")
        genre = genre.replace("'", "")
        #genre = genre.replace(" ", "")
        x = genre.split(",")
        genre_list.append(x)
        
for genre in genre_list:
    for sub_genre in genre:
        sub_genre_lst.append(sub_genre)
        
genre_pd_1980s = pd.DataFrame(sub_genre_lst)
genre_pd_1980s = genre_pd_1980s.rename(columns={0: "genre"})
genre_pd_1980s = genre_pd_1980s['genre'].str.lstrip(" ")

genre_pd_1980s.value_counts()
# Out:
# soft rock                  1541
# mellow gold                1404
# rock                       1116
# album rock                 1106
# new wave pop                922
# classic rock                805
# dance rock                  648
# new romantic                511
# quiet storm                 499
# new wave                    490
# hard rock                   478
# disco                       462
# folk rock                   460
# adult standards             429
# funk                        387
# motown                      361
# art rock                    344
# soul                        321
# heartland rock              296
# yacht rock                  291
# urban contemporary          260
# synthpop                    252
# post-disco                  245
# country rock                240
# pop rock                    217
# europop                     210
# folk                        209
# dance pop                   208
# new jack swing              204
# ...

# %%
mode_1980s = top1980_df["mode"]
mode_1980s=mode_1980s.replace(to_replace=True, value="Major")
mode_1980s=mode_1980s.replace(to_replace=False, value="Minor")
mode_1980s.value_counts()
# Out:
# Major    2537
# Minor    1055
# Name: mode, dtype: int64

# %%
top1980_df.hist(column = "key", bins = 12,ec='black')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x14e46bc90>]],
#       dtype=object)

# %%
top1980_df.hist(column = "time_signature", bins = 10, ec='black')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x14e490d10>]],
#       dtype=object)

# %%
top1980_df.plot(kind='scatter',x='week_position',y='spotify_track_duration_ms',color='red', title = "1970s Track Duration")
plt.show()

# %%
top1980_df_seconds = top1980_df['spotify_track_duration_ms']*0.001
top1980_df_seconds.hist()

# %%
top1980_df_seconds.describe()
# Out:
# count    3592.000000
# mean      256.605280
# std        56.085194
# min        90.950000
# 25%       221.400000
# 50%       247.814000
# 75%       284.079250
# max       736.862000
# Name: spotify_track_duration_ms, dtype: float64

# %%
top1970_df.hist(column = "loudness")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x14350ef50>]],
#       dtype=object)

# %%
top1980_df["loudness"].describe()
# Out:
# count    3592.000000
# mean       -9.867192
# std         3.450502
# min       -25.487000
# 25%       -12.374750
# 50%        -9.781500
# 75%        -7.120750
# max        -2.100000
# Name: loudness, dtype: float64

# %%
top1980_df.hist(column = "danceability")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x143b85b90>]],
#       dtype=object)

# %%
top1980_df["danceability"].describe()
# Out:
# count    3592.000000
# mean        0.626632
# std         0.139279
# min         0.126000
# 25%         0.540000
# 50%         0.633500
# 75%         0.727000
# max         0.988000
# Name: danceability, dtype: float64

# %%
top1980_df.hist(column = "energy")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x143fc8b10>]],
#       dtype=object)

# %%
top1980_df["energy"].describe()
# Out:
# count    3592.000000
# mean        0.654817
# std         0.192133
# min         0.020400
# 25%         0.521000
# 50%         0.674000
# 75%         0.808000
# max         0.995000
# Name: energy, dtype: float64

# %%
top1980_df.hist(column = "acousticness")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x143fc8e90>]],
#       dtype=object)

# %%
top1980_df["acousticness"].describe()
# Out:
# count    3592.000000
# mean        0.203719
# std         0.213713
# min         0.000024
# 25%         0.036775
# 50%         0.126000
# 75%         0.303000
# max         0.990000
# Name: acousticness, dtype: float64

# %%
top1980_df.hist(column = "valence")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1435be050>]],
#       dtype=object)

# %%
top1980_df["valence"].describe()
# Out:
# count    3592.000000
# mean        0.659995
# std         0.231550
# min         0.040000
# 25%         0.504000
# 50%         0.703500
# 75%         0.855000
# max         0.989000
# Name: valence, dtype: float64

# %%
top1980_df.hist(column = "tempo")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x143b93f50>]],
#       dtype=object)

# %%
top1980_df["tempo"].describe()
# Out:
# count    3592.000000
# mean      121.373357
# std        24.223259
# min        54.028000
# 25%       107.253250
# 50%       120.006500
# 75%       132.963750
# max       209.758000
# Name: tempo, dtype: float64

# %%
array = [0,2,7,9]
song1980s = top1980_df[top1980_df["week_position"]<10]
song1980s = song1980s[song1980s["key"].isin(array)]
song1980s = song1980s[song1980s["time_signature"]==4]
song1980s = song1980s[song1980s["spotify_track_duration_ms"] > 2.400000e+05]
song1980s = song1980s[song1980s["spotify_track_duration_ms"] < 2.600000e+05]
song1980s = song1980s[song1980s["loudness"] > -10.5]
song1980s = song1980s[song1980s["loudness"] < -9]
song1980s = song1980s[song1980s["danceability"] > .57]
song1980s = song1980s[song1980s["danceability"] < .85]
song1980s = song1980s[song1980s["energy"] > .59]
song1980s = song1980s[song1980s["energy"] < .75]
song1980s = song1980s[song1980s["acousticness"] < .2]
song1980s = song1980s[song1980s["valence"] > .5]
song1980s = song1980s[song1980s["tempo"] > 100]
song1980s = song1980s[song1980s["tempo"] < 130]
song1980s
# Out:
#                                    songid  week_position  year  \
# 804     Out Of TouchDaryl Hall John Oates              1  1984
# 2144  Running With The NightLionel Richie              7  1983
# 3427             Eye Of The TigerSurvivor              1  1982
#
#                   performer                    song  \
# 804   Daryl Hall John Oates            Out Of Touch
# 2144          Lionel Richie  Running With The Night
# 3427               Survivor        Eye Of The Tiger
#
#                                           spotify_genre  \
# 804   ['album rock', 'classic rock', 'mellow gold', ...
# 2144  ['adult standards', 'disco', 'mellow gold', 'm...
# 3427   ['album rock', 'hard rock', 'rock', 'soft rock']
#
#             spotify_track_id  \
# 804   7o67roCVsFiCt7Cf0ZLOJq
# 2144  3dciOkDSHPrhvriovMdw8N
# 3427  2KH16WveTQWT6KOG9Rg6e2
#
#                               spotify_track_preview_url  \
# 804   https://p.scdn.co/mp3-preview/d16ea3556110867f...
# ...

# %%
song1980s["danceability"]
# Out:
# 804     0.806
# 2144    0.766
# 3427    0.817
# Name: danceability, dtype: float64

# %%
genre_list = []
sub_genre_lst = []

for genre in top1990_df["spotify_genre"]:
    if type(genre) == str and genre != "[]":
        genre = genre.replace("[", "")
        genre = genre.replace("]", "")
        genre = genre.replace("'", "")
        #genre = genre.replace(" ", "")
        x = genre.split(",")
        genre_list.append(x)
        
for genre in genre_list:
    for sub_genre in genre:
        sub_genre_lst.append(sub_genre)
        
genre_pd_1990s = pd.DataFrame(sub_genre_lst)
genre_pd_1990s = genre_pd_1990s.rename(columns={0: "genre"})
genre_pd_1990s = genre_pd_1990s['genre'].str.lstrip(" ")

genre_pd_1990s.value_counts()
# Out:
# urban contemporary         499
# r&b                        477
# dance pop                  462
# rock                       426
# hip hop                    415
# new jack swing             415
# hip pop                    339
# quiet storm                329
# pop rock                   325
# soft rock                  299
# new wave pop               285
# mellow gold                267
# rap                        263
# neo soul                   236
# album rock                 234
# gangster rap               223
# pop                        205
# country                    205
# hardcore hip hop           188
# hard rock                  169
# permanent wave             168
# alternative rock           147
# hip house                  143
# country road               142
# pop rap                    142
# east coast hip hop         141
# post-grunge                141
# classic rock               139
# funk                       139
# europop                    137
# ...
