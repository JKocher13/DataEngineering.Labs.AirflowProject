# %%
import pandas as pd

# %%
billboard_df = pd.read_csv("./data/Hot Stuff.csv")

# %%
spotify_df = pd.read_csv("./data/Hot 100 Audio Features.csv")

# %%
billboard_df
# Out:
#                                                       url      WeekID  \
# 0       http://www.billboard.com/charts/hot-100/1958-0...    8/2/1958
# 1       http://www.billboard.com/charts/hot-100/1995-1...   12/2/1995
# 2       http://www.billboard.com/charts/hot-100/1997-1...  10/11/1997
# 3       http://www.billboard.com/charts/hot-100/2006-0...    7/1/2006
# 4       http://www.billboard.com/charts/hot-100/2009-1...  10/24/2009
# ...                                                   ...         ...
# 320490  https://www.billboard.com/charts/hot-100/2019-...    1/5/2019
# 320491  https://www.billboard.com/charts/hot-100/2019-...   12/7/2019
# 320492  https://www.billboard.com/charts/hot-100/2019-...  12/14/2019
# 320493  https://www.billboard.com/charts/hot-100/2019-...  12/21/2019
# 320494  https://www.billboard.com/charts/hot-100/2019-...  12/28/2019
#
#         Week Position                                               Song  \
# ...

# %%
grouped_billboard_df = billboard_df.groupby(["Song","Performer"]).agg({"Week Position":[min]})

grouped_billboard_df
# Out:
#                                                                                          Week Position
#                                                                                                    min
# Song                                             Performer
# "B" Girls                                        Young And Restless                                 54
# "Cherry Cherry" from Hot August Night            Neil Diamond                                       31
# "Having A Party" Medley                          The Ovations (Featuring Louis Williams)            56
# "Joy" Pt. I                                      Isaac Hayes                                        30
# "Roots" Medley                                   Quincy Jones                                       57
# ...                                                                                                ...
# ...

# %%
billboard_df.loc[billboard_df["Song"] == "Jingle Bell Rock"]
# Out:
#                                                       url      WeekID  \
# 14317   http://www.billboard.com/charts/hot-100/1958-1...  12/20/1958
# 28510   http://www.billboard.com/charts/hot-100/1961-1...   12/9/1961
# 85018   http://www.billboard.com/charts/hot-100/1958-1...  12/27/1958
# 85502   http://www.billboard.com/charts/hot-100/1961-1...  12/16/1961
# 116000  http://www.billboard.com/charts/hot-100/1962-0...    1/6/1962
# 126618  http://www.billboard.com/charts/hot-100/1961-1...  12/23/1961
# 127909  http://www.billboard.com/charts/hot-100/1959-0...    1/3/1959
# 177460  http://www.billboard.com/charts/hot-100/1961-1...  12/30/1961
# 183140  http://www.billboard.com/charts/hot-100/1959-0...   1/10/1959
# 217855  http://www.billboard.com/charts/hot-100/1962-0...   1/13/1962
# 314974  http://www.billboard.com/charts/hot-100/1960-1...  12/10/1960
# 315258  http://www.billboard.com/charts/hot-100/1960-1...  12/17/1960
# ...
